# %% [markdown]
# ### For Loop

# %%
for i in range(1,100):
  print(i)

# %% [markdown]
# ### While Loop

# %%
i = 1

while i < 10:
  print(i)
  i = i + 3
  print("Hello world!")

# %% [markdown]
# ### Function

# %%
def addFive(x):
  print("Hello world!")
  return x + 5

# %%
y = addFive(19)
print(y)

# %%
print("Hello Hanan")
print("Hello Dinsefo")
print("Hello Amina")

# %%
def greet(name):
  print("Hello", name)
  return 100

# %%
greet("Hanan")

# %%
y = greet("Amina")
print(y)

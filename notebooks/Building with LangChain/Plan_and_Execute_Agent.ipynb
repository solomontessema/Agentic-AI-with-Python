# %% [markdown]
# <a href="https://colab.research.google.com/github/solomontessema/Agentic-AI-with-Python/blob/main/notebooks/Building%20with%20LangChain/Plan_and_Execute_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table>
#   <tr>
#     <td><img src="https://ionnova.com/img/ionnova_logo_name_2.png" width="120px"></td>
#     <td><h1>Plan-and-Execute Agent</h1></td>
#   </tr>
# </table>

# %% [markdown]
# ### Step 1: Create plan_agent.py

# %%
# !pip install -r https://raw.githubusercontent.com/solomontessema/Agentic-AI-with-Python/main/requirements.txt

# %%
from dotenv import load_dotenv
from langchain.chat_models import ChatOpenAI
from langchain.tools import Tool

# import your API KEY
load_dotenv()

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)


def get_product_price(product_name: str) -> str:
    return f"Simulated price for '{product_name}': $19.99 with Prime shipping."

price_tool = Tool(
    name="get_product_price",
    func=get_product_price,
    description="Fetch simulated pricing data for a given Amazon product name."
)

# Create an Agent
agent = initialize_agent(
    tools=[price_tool],
    llm=llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True
)

# Test the Agent
response = agent.run("What's the price of a wireless mouse on Amazon?")
print(response)

# %% [markdown]
# ### Step 2: Evaluate Agent Reasoning
#
# Observe:
#
# * How the agent structures a plan
#
# * Which tools it invokes per subtask
#
# * Whether results are summarized coherently

# %% [markdown]
# ### Step 3: Extend with Memory (Optional)
#
# Consider integrating memory to allow the agent to retain context across multiple queries. This can enhance multi-step reasoning and improve user experience in dynamic workflows.

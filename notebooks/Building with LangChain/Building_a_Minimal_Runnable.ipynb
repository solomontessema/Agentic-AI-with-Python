# %% [markdown]
# <a href="https://colab.research.google.com/github/solomontessema/Agentic-AI-with-Python/blob/main/notebooks/Building%20with%20LangChain/Building_a_Minimal_Runnable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table> <tr> <td><img src="https://ionnova.com/img/ionnova_logo_2.png" width="120px"></td> <td><h1 style="margin: 0;">Academy</h1></td> </tr> </table>
#
# ---

# %% [markdown]
# <h1>Building a Minimal Runnable</h1>

# %% [markdown]
# ### Basic LangChain Runnable to answer a natural language question.

# %%
# !pip install -qU langchain langchain-openai python-dotenv

# %%
# runnable_app.py
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

prompt = PromptTemplate(
    input_variables=["question"],
    template="Answer clearly and concisely: {question}"
)

# Build the pipeline: Prompt → LLM → Parser
runnable = prompt | llm | StrOutputParser()

response = runnable.invoke({"question": "What is LangChain used for?"})
print(response)
